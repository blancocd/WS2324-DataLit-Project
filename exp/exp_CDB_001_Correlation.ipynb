# %%
import pandas as pd
data = pd.read_csv("./dat/cleaned/data_for_regression.csv", index_col=0)
data.corr()
# Out:
#                         Happiness Score  Corruption       GDP  Generosity  \
# Happiness Score                1.000000   -0.468875  0.804728    0.206687
# Corruption                    -0.468875    1.000000 -0.341853   -0.298737
# GDP                            0.804728   -0.341853  1.000000    0.004066
# Generosity                     0.206687   -0.298737  0.004066    1.000000
# Freedom of Choice              0.560623   -0.521456  0.385090    0.344244
# Social Support                 0.729625   -0.242951  0.714315    0.094778
# Suicide Rates                 -0.139530    0.012192 -0.058529   -0.180034
# Schizophrenia                  0.647949   -0.236839  0.736636    0.174925
# Depression                    -0.323262    0.037078 -0.398647   -0.088051
# Anxiety                        0.466371   -0.260925  0.453433    0.179975
# Bipolar Disorder               0.585289   -0.370571  0.466772    0.037925
# Eating Disorder                0.746517   -0.528430  0.746016    0.183000
# ...

# %%
import pandas as pd
data = pd.read_csv("./dat/cleaned/data_for_regression_Germany.csv")
data.drop(columns=['Unnamed: 0'], inplace=True)
data.corr()
# Out:
#                         Happiness Score  Corruption       GDP  Generosity  \
# Happiness Score                1.000000   -0.936415  0.817466   -0.207910
# Corruption                    -0.936415    1.000000 -0.865247   -0.026615
# GDP                            0.817466   -0.865247  1.000000   -0.163825
# Generosity                    -0.207910   -0.026615 -0.163825    1.000000
# Freedom of Choice              0.591730   -0.551430  0.512858   -0.551198
# Social Support                -0.548715    0.655811 -0.763703   -0.203738
# Suicide Rates                 -0.570383    0.634067 -0.804472   -0.063755
# Schizophrenia                  0.757996   -0.728749  0.810496   -0.170248
# Depression                    -0.266187    0.160703 -0.293864    0.233150
# Anxiety                        0.736510   -0.789683  0.772872   -0.170035
# Bipolar Disorder              -0.866016    0.876633 -0.864700    0.045607
# Eating Disorder                0.918229   -0.945426  0.960081   -0.142566
# ...
