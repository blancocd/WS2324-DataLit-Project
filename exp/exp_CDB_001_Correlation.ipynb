# %% [markdown]
# We clean the data with the next 3 following scripts. Feel free to check out the cleaning process.

# %%
import os
os.chdir("..")
if not (os.path.exists("./dat/cleaned")):
    os.mkdir("./dat/cleaned")

# %run -i './src/CLM_001_DataCleaningSuicideRates.py'
# %run -i './src/CLM_001_DataCleaningMentalSubstanceDisorders.py'
# %run -i './src/LVV_001_DataCleaningFeaturesWHR.py'

# %% [markdown]
# Next we run the final data preparation code for the regression analysis.

# %%
# %run -i './src/DataForRegression.py'

# %% [markdown]
# Next we can see the correlation of the features:

# %%
import pandas as pd
data = pd.read_csv("./dat/cleaned/data_for_regression.csv")
data.corr()
# Out:
#                         Unnamed: 0  Happiness Score  Corruption       GDP  \
# Unnamed: 0                1.000000        -0.073810   -0.035013 -0.114085
# Happiness Score          -0.073810         1.000000   -0.468875  0.804728
# Corruption               -0.035013        -0.468875    1.000000 -0.341853
# GDP                      -0.114085         0.804728   -0.341853  1.000000
# Generosity                0.083979         0.206687   -0.298737  0.004066
# Freedom of Choice         0.054147         0.560623   -0.521456  0.385090
# Social Support            0.058647         0.729625   -0.242951  0.714315
# Suicide Rates             0.096876        -0.139530    0.012192 -0.058529
# Schizophrenia            -0.077886         0.647949   -0.236839  0.736636
# Depression                0.039437        -0.323262    0.037078 -0.398647
# Anxiety                  -0.059093         0.466371   -0.260925  0.453433
# Bipolar Disorder         -0.103883         0.585289   -0.370571  0.466772
# ...
